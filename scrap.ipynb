# %%
import time
import requests
import re
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from bs4 import BeautifulSoup

# %%
labels = ['Long Term Rentals', 'Room Rentals & Roommates', 'Short Term Rentals']

# %%
base_url = 'https://www.kijiji.ca/'

# %%
start_page = 1
short_term_url = base_url + f'b-short-term-rental/ontario/page-{start_page}/c42l9004'
room_and_rental_term_url = base_url + f'b-room-rental-roommate/ontario/page-{start_page}/c36l9004'

# %%
def get_links(url: str) -> list:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    ads = soup.find_all("div", attrs={'class': 'search-item'})
    # remove third-party ad
    ads = [x for x in ads if ("cas-channel" not in x["class"]) & ("third-party" not in x["class"])]

    # create a list to store all of the URLs from the 
    ad_links = []
    for ad in ads:
        # parse the link from the ad
        link = ad.find_all("a", {"class": "title"})
        # add the link to the list
        for l in link:
            ad_links.append(base_url[:-1] + l["href"])
    return ad_links

# %%
long_term_list = []
for i in range(1, 5):
    long_term_url = base_url + f'b-apartments-condos/city-of-toronto/page-{i}/c37l1700273?ll=43.653226%2C-79.383184&address=Toronto%2C+ON&radius=18.0'
    long_term_list.append(get_links(long_term_url))
# short_term_list = get_links(short_term_url)
# room_and_rental_term_list = get_links(room_and_rental_term_url)

# %%
def get_context(url: str) -> None:
    global df1
    print(url)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    # get ad title
    try:
        title = soup.find("h1", class_=lambda cls: cls and 'title' in cls).text
    except AttributeError:
        
        title = None


    # get ad price
    try:
        # price = soup.find("span", attrs={"itemprop": "price"}).text
        price = soup.find("div", class_=lambda cls: cls and 'price' in cls).text
    except AttributeError:
        price = None

    # get date posted
    try:
        datetime_obj = soup.find("time")
        date_posted = datetime.fromisoformat(datetime_obj['datetime'][:-1])
    except (AttributeError, TypeError):
        date_posted = None

    # get ad description
    try:
        # description = soup.find("div", attrs={"itemprop": "description"}).text
        desc = soup.find("div", class_=lambda cls: cls and 'descriptionContainer' in cls)
        desc_html = desc.prettify()
        cleaned_text = re.sub('<.*?>', '', desc_html)
        description = re.sub(r'\n+\s+', '', cleaned_text)
    except AttributeError:
        description = None

    # get the ad city
    try:
        address = soup.find("span", attrs={"itemprop": "address"}).text
    except AttributeError:
        address = None
    # apend information to the dataframe
    df1 = df1.append({
        "title": title,
        "price": price,
        "description": description,
        "date_posted": date_posted,
        "address": address, 
        "url": url},
        ignore_index=True
    )

# %%
df = pd.DataFrame(columns=['title', 'description', 'price', 'date_posted', 'address', 'url'])

# %%
df1 = pd.DataFrame(columns=['title', 'description', 'price', 'date_posted', 'address', 'url'])

# %%
for url in long_term_list[3]:
    get_context(url)
    # context = get_context(url)
    # print(context)
    # df1.append(context, ignore_index=True)
# pd.concat([df, df1], ignore_index=True)
# Out:
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/renovated-1-bedroom-yonge-and-davisville/1646179670
# https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region/2-bdrm-10-blackfriar-ave-186-kingsview-blvd-15-55-brides/1631153619
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/beautiful-one-bedroom/1651159435
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-apartments-for-rent-on-jackes-avenue/1646071531
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-month-free-large-1-bedroom-toronto-apartment-near-subway/1649856290
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/upscale-2-bedroom-suite-don-mills-sheppard-ave-e/1631277280
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-legal-basement-apt-april-1-new/1651145779
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/bright-one-bedroom-penthouse-w-private-rooftop-terrace/1651094368
# https://www.kijiji.ca/v-apartments-condos/city-of-toronto/brand-new-downtown-1-bedroom-condo-w-lakeview-one-month-free/1651145331
# https://www.kijiji.ca/v-apartments-condos/mississauga-peel-region
# 9   3 Bdrm Townhouse - 1560 Bloor Street, 3455 Hav...
# 10  3 Bdrm Townhouse - 1560 Bloor Street, 3455 Hav...
# 11  O'Connor Apartments - 1 Bedroom Apartment for ...
# 12    Dawes Apartments - 1 Bedroom Apartment for Rent
# 13    2 Bdrm à louer au 1216 York Mills Road, Toronto
# 14  2 Bdrm available at 1216 York Mills Road, Toronto
# 15    1 Bdrm à louer au 1216 York Mills Road, Toronto
# 16  1 Bdrm available at 1216 York Mills Road, Toronto
# 17                      One bedroom basement for rent
# 18  Hidden Gem larger then a family house (3br - 1...
# 19       Broadview Loft For Rent with Private Terrace
# 20  Large, renovated 2 bed apartment, March 1st, $...
# 21  **Spacious 2 bedroom apartment for rent on Yon...
# 22  1 Bedroom Apartment for Rent - 100 Gloucester ...
# 23  Bachelor Apartment for Rent - 100 Gloucester S...
# 24  3BR 2BATH FOR RENT IN SCARBOROUGH - BRIGHT NEW...
# 25  2 Bedroom + Den Apartment For Rent near Ossing...
# 26           TORONTO WATERFRONT ONE BEDROOM PLUS DEN.
# 27               TORONTO WATERFRONT TWO BEDROOMS+DEN!
# 28      1 Bedroom Available | $500 credit | CALL NOW!
# 29  1 Bedroom + Den Available | $500 credit | Call...
# 30        1 Bedroom Available | Call now for Details!
# 31  1 Bedroom Available | Get $250 off FMR! - CALL...
# 32      1 Bedroom Available  | Call for more details!
# 33                Townhouse lease bayview finch 2850$
# 34  FURNISHED 4Bedroom MainFoor for Students/Inter...
# 35  Parkdale 2 Bedroom Apartment for Rent - 115 Do...
# 36  Parkdale 1 Bedroom Apartment for Rent - 115 Do...
# 37  2 Bedrooms Apartment for Rent - 100 Gloucester...
# 38  Etobicoke 2 Bedroom Apartment for Rent - 1 Cro...
# 39  Bachelor Apartment for Rent - 80 Wellesley Str...
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
#
#                                           description           price  \
# 0   DescriptionViewings:Please call or text our Le...          $2,395
# 1   DescriptionVisit our Website: https://www.capr...          $2,385
# 2   DescriptionSpacious and newly-renovated lovely...  $2,380FEATURED
# 3   DescriptionJoin Us for Our In-person Open Hous...          $3,098
# 4   DescriptionAt Last, This Is What You've Been S...          $2,299
# 5   DescriptionOur renovated apartments at 25 Leit...          $2,747
# 6   DescriptionBeautiful Newly Renovated 2 Bedroom...          $2,000
# 7   DescriptionRenovated penthouse; top appliances...          $3,500
# 8   Description* Move in by March 1 and get one mo...          $2,290
# 9   DescriptionVisit our Website: https://www.capr...          $2,965
# 10  DescriptionVisit our Website: https://www.capr...          $2,965
# 11  DescriptionO'Connor Apartments is a clean and ...          $1,750
# 12  Description★  New Kitchen With Granite Counter...          $1,750
# 13  DescriptionVisit our Website: https://www.capr...          $2,590
# 14  DescriptionVisit our Website: https://www.capr...          $2,590
# 15  DescriptionVisit our Website: https://www.capr...          $2,245
# 16  DescriptionVisit our Website: https://www.capr...          $2,245
# 17  DescriptionOne bedroom basement\nNew renovated...          $1,800
# 18  DescriptionBeautiful three bedroom Victorian-e...          $4,250
# 19  DescriptionHard Loft Beauty! 1100+ Square Ft. ...  $3,950FEATURED
# 20  DescriptionLarge, renovated, 2 bedroom apartme...          $2,349
# 21  DescriptionFairlawn Apartments NOW RENTING.\n3...  $2,495FEATURED
# 30  https://www.kijiji.ca/v-apartments-condos/city...
# 31  https://www.kijiji.ca/v-apartments-condos/city...
# 32  https://www.kijiji.ca/v-apartments-condos/city...
# 33  https://www.kijiji.ca/v-apartments-condos/city...
# 34  https://www.kijiji.ca/v-apartments-condos/city...
# 35  https://www.kijiji.ca/v-apartments-condos/city...
# 36  https://www.kijiji.ca/v-apartments-condos/city...
# 37  https://www.kijiji.ca/v-apartments-condos/city...
# 38  https://www.kijiji.ca/v-apartments-condos/miss...
# 39  https://www.kijiji.ca/v-apartments-condos/city...
# 40  https://www.kijiji.ca/v-apartments-condos/city...
# 41  https://www.kijiji.ca/v-apartments-condos/city...
# 42  https://www.kijiji.ca/v-apartments-condos/city...
# 43  https://www.kijiji.ca/v-apartments-condos/city...
# 44  https://www.kijiji.ca/v-apartments-condos/city...

# %%
df = pd.concat([df1, df], ignore_index=True)

# %%
df
# Out:
#                                                  title  \
# 0           Renovated 1 Bedroom @ Yonge and Davisville
# 1    2 Bdrm - 10 Blackfriar Ave., 186 Kingsview Blv...
# 2                               Beautiful One Bedroom
# 3       2 Bedroom Apartments for Rent on Jackes Avenue
# 4    1 MONTH FREE! Large 1-Bedroom Toronto Apartmen...
# ..                                                 ...
# 175                                               None
# 176                                               None
# 177                                               None
# 178                                               None
# 179                                               None
#
#                                            description           price  \
# 0    DescriptionViewings:Please call or text our Le...          $2,395
# 1    DescriptionVisit our Website: https://www.capr...          $2,385
# 2    DescriptionSpacious and newly-renovated lovely...  $2,380FEATURED
# 3    DescriptionJoin Us for Our In-person Open Hous...          $3,098
# 4    DescriptionAt Last, This Is What You've Been S...          $2,299
# ..                                                 ...             ...
# 175                                               None            None
# 176                                               None            None
# 177                                               None            None
# 178                                               None            None
# 179                                               None            None
#
#             date_posted                                            address  \
# 0   2023-02-20 12:43:47           155 Balliol Street, Toronto, ON, M4S 1C2
# 1   2023-01-28 00:07:33  10 Blackfriar Ave., 186 Kingsview Blvd., 15 & ...
# 2   2023-02-21 17:59:05                                    M1L 1W3, Canada
# 3   2023-02-21 14:12:46              7 Jackes Avenue, Toronto, ON, M4T 1E3
# 4   2023-02-09 13:24:01           377 Ridelle Avenue, Toronto, ON, M6B 1K2
# ..                  ...                                                ...
# 175                 NaT                                               None
# 176                 NaT                                               None
# 177                 NaT                                               None
# 178                 NaT                                               None
# 179                 NaT                                               None
#
#                                                    url
# 0    https://www.kijiji.ca/v-apartments-condos/city...
# 1    https://www.kijiji.ca/v-apartments-condos/miss...
# 2    https://www.kijiji.ca/v-apartments-condos/city...
# 3    https://www.kijiji.ca/v-apartments-condos/city...
# 4    https://www.kijiji.ca/v-apartments-condos/city...
# ..                                                 ...
# 175  https://www.kijiji.ca/v-apartments-condos/city...
# 176  https://www.kijiji.ca/v-apartments-condos/city...
# 177  https://www.kijiji.ca/v-apartments-condos/city...
# 178  https://www.kijiji.ca/v-apartments-condos/city...
# 179  https://www.kijiji.ca/v-apartments-condos/city...
#
# [180 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# title          20
# description    20
# price          20
# date_posted    20
# address        20
# url             0
# dtype: int64

# %%
final_df = df.copy()
final_df.shape
# Out:
# (180, 6)

# %%
final_df.to_csv("kijiji_watch_data.csv")
